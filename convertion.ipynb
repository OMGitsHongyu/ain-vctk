# %%
from analyzer import *

import os
import numpy as np
import librosa
import glob
from sklearn.model_selection import train_test_split
import IPython.display as ipd

# %%
fnames = ['data/matrix_sample/225/pair/test/p226_003-p225_003.bin', 'data/matrix_sample/225/pair/test/p226_003-p225_003.bin','data/matrix_sample/225/pair/test/p226_003-p225_003.bin','data/matrix_sample/225/pair/test/p226_003-p225_003.bin','data/matrix_sample/225/pair/test/p226_003-p225_003.bin','data/matrix_sample/225/pair/test/p226_003-p225_003.bin','data/matrix_sample/225/pair/test/p226_003-p225_003.bin','data/matrix_sample/225/pair/test/p226_003-p225_003.bin']

# %%
normalizer = Tanhize(xmax=np.fromfile('data/matrix_sample/225/etc/xmax.npf'),
                     xmin=np.fromfile('data/matrix_sample/225/etc/xmin.npf'))
a = read_pair_batch_numpy(fnames, record_lines=100000, mode='test')
# Out:
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32

# %%
a
# Out:
# (array([[[[-1.66737103],
#           [-1.66729271],
#           [-1.66705966],
#           ...,
#           [-6.74241543],
#           [-6.75640106],
#           [-6.7611289 ]],
#
#          [[-3.04389501],
#           [-3.04366446],
#           [-3.0429759 ],
#           ...,
#           [-6.62015247],
#           [-6.63209534],
#           [-6.63609743]],
#
#          [[-3.96400619],
#           [-3.96383929],
#           [-3.96334457],
#           ...,
#           [-6.47928381],
#           [-6.48126698],
#           [-6.48184252]],
#
#          ...,
#          [[-1.73299241],
#           [-1.73305368],
#           [-1.73323822],
#           ...,
#           [-8.12555408],
#           [-8.12950611],
#           [-8.13081264]],
#
#          [[-1.63626182],
#           [-1.63620436],
#           [-1.6360327 ],
#           ...,
#           [-8.85662746],
#           [-8.86493969],
#           [-8.86773872]],
#
#          [[-2.08653259],
#           [-2.08634019],
# ...

# %%
normalizer = Tanhize(xmax=np.fromfile('data/225/etc/xmax.npf'),
                     xmin=np.fromfile('data/225/etc/xmin.npf'))
a1 = extract('./test/p225_001.wav')
a, b = read_pair_single_numpy('./test/p226_001-p225_001.bin', normalizer=normalizer, fields='all')

# %%
a, b = read_pair_single_numpy('./test/p226_001-p225_001.bin', record_lines=10000, normalizer=normalizer, fields='all')

# %%
a.shape
# Out:
# (269, 1029)

# %%
# a_b = np.hstack((normalizer.backward_process(a[:,:513]),a[:,513:]))
ipd.Audio(pw2wav(a), rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
SP_DIM = 513
FEAT_DIM = 1029

def convert_feature(spec, other_feature, src, trg, normalizer=None):
    if normalizer:
        spec = normalizer.backward_process(spec)
    f0 = convert_f0(other_feature[:,-3], src, trg)
    print other_feature[:,-3], f0
    return np.hstack((spec, other_feature[:,:-3], f0.reshape(-1,1), other_feature[:,-2].reshape(-1,1)))

# %%
k = convert_feature(a[:,:513],a[:,513:], (4.8286185, 0.16229385), (5.2577271, 0.15516736), normalizer=normalizer)
# Out:
# [   0.            0.            0.            0.            0.            0.
#     0.          114.22120667  127.30312347  131.80223083  148.64781189
#   160.78158569  153.16845703  150.02259827  151.34846497  154.64573669
#   160.20899963  160.20899963  160.20899963  160.20899963  160.20899963
#   160.20899963  161.3651886   157.85284424  153.75924683  152.50231934
#   152.50231934  152.50231934  152.50231934  152.50231934  152.50231934
#   152.50231934  152.50231934  152.50231934  152.50231934  151.87438965
#   151.59864807  152.19827271  150.99763489  151.16682434  150.67076111
#   148.68623352  150.36210632  149.71090698  149.07536316  150.1864624
#   148.82661438  148.71040344  148.67437744  147.80677795  148.06559753
#   147.84103394  148.02938843  147.82133484  147.55101013  148.08013916
#   147.75080872  142.48461914  138.95602417  134.76429749  131.4974823
#   125.82338715  126.19613647  126.19613647    0.            0.            0.
# ...

# %%
ipd.Audio(pw2wav(a), rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a[:,513:][:,-3]
# Out:
# array([   0.        ,    0.        ,    0.        ,    0.        ,
#           0.        ,    0.        ,    0.        ,  114.22120667,
#         127.30312347,  131.80223083,  148.64781189,  160.78158569,
#         153.16845703,  150.02259827,  151.34846497,  154.64573669,
#         160.20899963,  160.20899963,  160.20899963,  160.20899963,
#         160.20899963,  160.20899963,  161.3651886 ,  157.85284424,
#         153.75924683,  152.50231934,  152.50231934,  152.50231934,
#         152.50231934,  152.50231934,  152.50231934,  152.50231934,
#         152.50231934,  152.50231934,  152.50231934,  151.87438965,
#         151.59864807,  152.19827271,  150.99763489,  151.16682434,
#         150.67076111,  148.68623352,  150.36210632,  149.71090698,
#         149.07536316,  150.1864624 ,  148.82661438,  148.71040344,
#         148.67437744,  147.80677795,  148.06559753,  147.84103394,
#         148.02938843,  147.82133484,  147.55101013,  148.08013916,
# ...
